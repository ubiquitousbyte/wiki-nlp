# %%
from wiki_nlp.data.dataset import WikiDataset, WikiExample
from wiki_nlp.models.dm import DM
from wiki_nlp.services.dm_service import DMService
from wiki_nlp.data.domain import Document, Section, Paragraph

# %%
import matplotlib.pyplot as plt
from numpy.linalg import norm 
import numpy as np
import torch
from sklearn.decomposition import PCA

# %%
dm_service = DMService(
    model_state_path="document_dm_state",
    dataset_path="document_dataset"
)
# Translation of some paragraphs from https://en.wikipedia.org/wiki/Artificial_intelligence to German
# The model finds that the top 2 closest documents are 
# https://de.wikipedia.org/wiki/Wissen and https://de.wikipedia.org/wiki/K%C3%BCnstliche_Intelligenz
doc = Document(
    id='',
    title='InformatikTest',
    excerpt = """
    Künstliche Intelligenz (KI) ist Intelligenz, die von Maschinen demonstriert wird, im Gegensatz zur natürlichen Intelligenz
    von Menschen oder Tieren. Führende KI-Lehrbücher definieren das Feld als das Studium von „intelligenten Agenten“: 
    jedes System, das seine Umgebung wahrnimmt und Maßnahmen ergreift, die seine Chance maximieren, seine Ziele zu erreichen.[a]
    Einige populäre Berichte verwenden den Begriff „künstliche Intelligenz“, um Maschinen zu beschreiben, die ahmen „kognitive“ 
    Funktionen nach, die Menschen mit dem menschlichen Verstand assoziieren, wie „Lernen“ und „Problemlösen“, diese Definition 
    wird jedoch von großen KI-Forschern abgelehnt.[b]
    KI-Anwendungen umfassen fortschrittliche Websuchmaschinen (z. B. Google), Empfehlungssysteme (verwendet von YouTube,
    Amazon und Netflix), das Verstehen menschlicher Sprache (z. B. Siri oder Alexa), selbstfahrende Autos (z. B. Tesla) 
    und Wettbewerb auf höchstem Niveau in strategischen Spielsystemen (wie Schach und Go)[2] Da Maschinen immer leistungsfähiger
    werden, werden Aufgaben, die als "Intelligenz" angesehen werden, oft aus der Definition von KI gestrichen, ein Phänomen, das
    als KI-Effekt bekannt ist.[3] Beispielsweise wird die optische Zeichenerkennung häufig von Dingen ausgeschlossen, die als KI
    angesehen werden,[4] da sie zu einer Routinetechnologie geworden ist.[5]
    Künstliche Intelligenz wurde 1956 als akademische Disziplin gegründet und erlebte in den Jahren danach mehrere Wellen des
    Optimismus,[6] [7] gefolgt von Enttäuschungen und dem Verlust von Finanzmitteln (bekannt als "KI-Winter"),[8] [9] gefolgt
    von neuen Ansätzen, Erfolg und erneuter Finanzierung.[7][10] Die KI-Forschung hat im Laufe ihres Lebens viele verschiedene
    Ansätze ausprobiert und verworfen, darunter die Simulation des Gehirns, die Modellierung menschlicher Problemlösungen, formale
    Logik, große Wissensdatenbanken und die Nachahmung von Tierverhalten. In den ersten Jahrzehnten des 21. Jahrhunderts hat das 
    hochmathematische statistische maschinelle Lernen das Feld dominiert, und diese Technik hat sich als sehr erfolgreich erwiesen
    und hilft, viele schwierige Probleme in Industrie und Wissenschaft zu lösen.[11][10]
    Die verschiedenen Teilbereiche der KI-Forschung zentrieren sich auf bestimmte Ziele und den Einsatz bestimmter Werkzeuge.
    Zu den traditionellen Zielen der KI-Forschung gehören logisches Denken, Wissensrepräsentation, Planung, Lernen, Verarbeitung
    natürlicher Sprache, Wahrnehmung und die Fähigkeit, Objekte zu bewegen und zu manipulieren.[c] Allgemeine Intelligenz
    (die Fähigkeit, ein beliebiges Problem zu lösen) gehört zu den langjährigen Laufzeitziele.[12] Um diese Probleme zu lösen,
    verwenden KI-Forscher Versionen der Suche und mathematische Optimierung, formale Logik, künstliche neuronale Netze und 
    Methoden, die auf Statistik, Wahrscheinlichkeit und Ökonomie basieren. KI stützt sich auch auf Informatik, Psychologie,
    Linguistik, Philosophie und viele andere Bereiche.
    """,
    source='mediawiki',
    sections=[
        Section(id='', title='', position='', paragraphs=[Paragraph(id='', text="""
        Maschinelles Lernen (ML), ein grundlegendes Konzept der KI-Forschung seit den Anfängen des Feldes,[k] ist das Studium
        von Computeralgorithmen, die sich durch Erfahrung automatisch verbessern.[l]
        Unüberwachtes Lernen findet Muster in einem Strom von Eingaben. Überwachtes Lernen erfordert, dass ein Mensch die 
        Eingabedaten zuerst beschriftet, und gibt es in zwei Hauptvarianten: Klassifikation und numerische Regression. 
        Die Klassifizierung wird verwendet, um zu bestimmen, in welche Kategorie etwas gehört – das Programm sieht eine Reihe von
        Beispielen für Dinge aus mehreren Kategorien und lernt, neue Eingaben zu klassifizieren. Regression ist der Versuch, eine
        Funktion zu erstellen, die die Beziehung zwischen Eingaben und Ausgaben beschreibt und vorhersagt, wie sich die Ausgaben 
        ändern sollten, wenn sich die Eingaben ändern. Sowohl Klassifikatoren als auch Regressionslerner können als 
        "Funktionsapproximatoren" angesehen werden, die versuchen, eine unbekannte (möglicherweise implizite) Funktion zu lernen; 
        Beispielsweise kann ein Spam-Klassifizierer als das Erlernen einer Funktion angesehen werden, die den Text einer E-Mail 
        einer von zwei Kategorien zuordnet, „Spam“ oder „kein Spam“.[69] Beim Reinforcement Learning wird der Agent für gute 
        Antworten belohnt und für schlechte bestraft. Der Agent klassifiziert seine Antworten, um eine Strategie für das Handeln 
        in seinem Problemraum zu entwickeln.[70]
        Die Theorie des computergestützten Lernens kann Lernende anhand der Rechenkomplexität, anhand der Stichprobenkomplexität 
        (wie viele Daten erforderlich sind) oder anhand anderer Optimierungskonzepte beurteilen.
        """)])
    ]
)
vec = dm_service.infer_vector(doc)
dists, indices = dm_service.most_similar(vec, topn=2)
for i, dist in enumerate(dists):
    print(f"{dist.item()}\n {dm_service._dataset[indices[i].item()]}")
# Out:
# Epoch 1 - 100%
# Loss tensor(4.0307)
# Epoch 2 - 100%
# Loss tensor(3.6563)
# Epoch 3 - 100%
# Loss tensor(3.7751)
# Epoch 4 - 100%
# Loss tensor(3.4223)
# Epoch 5 - 100%
# Loss tensor(3.7108)
# Epoch 6 - 100%- 40% - 80%
# Loss tensor(3.4152)
# Epoch 7 - 100%
# Loss tensor(3.3876)
# Epoch 8 - 100%
# Loss tensor(3.5729)
# Epoch 9 - 100%
# Loss tensor(3.3273)
# Epoch 10 - 100%
# Loss tensor(3.3725)
# Epoch 11 - 100%
# Loss tensor(2.9774)
# Epoch 12 - 100%
# Loss tensor(3.2250)
# Epoch 13 - 100%
# Loss tensor(3.1834)
# Epoch 14 - 100%- 40%
# Loss tensor(2.9360)
# Epoch 15 - 80% - 100%
# Loss tensor(3.3440)
# Epoch 16 - 100%
# Loss tensor(3.1369)
# Epoch 17 - 100%
# Loss tensor(2.6236)
# Epoch 18 - 100%
# Loss tensor(2.9766)
# Epoch 19 - 100%
# Loss tensor(2.6604)
# Epoch 20 - 100%
# Loss tensor(2.8808)
# Epoch 21 - 100%
# Loss tensor(2.9253)
# Epoch 22 - 100%
# Loss tensor(2.8908)
# Epoch 23 - 100%
# Loss tensor(2.5740)
# Epoch 24 - 100%
# Loss tensor(2.7035)
# Epoch 25 - 100%
# Loss tensor(2.6878)
# Epoch 26 - 100%
# Loss tensor(2.9033)
# Epoch 27 - 100%
# Loss tensor(2.7659)
# Epoch 28 - 80% - 100%
# Loss tensor(2.5452)
# Epoch 29 - 100%
# Loss tensor(2.6605)
# Epoch 30 - 100%
# Loss tensor(2.5169)
# Epoch 31 - 100%
# Loss tensor(2.5784)
# Epoch 32 - 100%
# Loss tensor(2.6702)
# Epoch 33 - 100%
# Loss tensor(2.5745)
# Epoch 34 - 100%
# Loss tensor(2.4629)
# Epoch 35 - 100%
# Loss tensor(2.6000)
# Epoch 36 - 80% - 100%
# Loss tensor(2.3550)
# Epoch 37 - 100%- 80%
# Loss tensor(2.4885)
# Epoch 38 - 100%
# Loss tensor(2.6116)
# Epoch 39 - 100%
# Loss tensor(2.7813)
# Epoch 40 - 100%
# Loss tensor(2.5349)
# Epoch 41 - 100%
# Loss tensor(2.7009)
# Epoch 42 - 100%
# Loss tensor(2.5827)
# Epoch 43 - 100%
# Loss tensor(2.3014)
# Epoch 44 - 60% - 80% - 100%
# Loss tensor(2.5758)
# Epoch 45 - 100%
# Loss tensor(2.5059)
# Epoch 46 - 100%
# Loss tensor(2.4518)
# Epoch 47 - 100%
# Loss tensor(2.3925)
# Epoch 48 - 100%
# Loss tensor(2.1975)
# Epoch 49 - 100%
# Loss tensor(2.3304)
# Epoch 50 - 80% - 100%
# Loss tensor(2.2642)
# Epoch 51 - 100%
# Loss tensor(2.2457)
# Epoch 52 - 100%
# Loss tensor(2.2564)
# Epoch 53 - 100%
# Loss tensor(2.2747)
# Epoch 54 - 100%
# Loss tensor(2.1735)
# Epoch 55 - 100%
# Loss tensor(2.1699)
# Epoch 56 - 100%
# Loss tensor(2.3287)
# Epoch 57 - 100%
# Loss tensor(2.2595)
# Epoch 58 - 100%
# Loss tensor(2.3079)
# Epoch 59 - 100%
# Loss tensor(2.4971)
# Epoch 60 - 100%
# Loss tensor(2.3331)
# Epoch 61 - 100%
# Loss tensor(2.3079)
# Epoch 62 - 100%
# Loss tensor(2.3347)
# Epoch 63 - 100%
# Loss tensor(2.2182)
# Epoch 64 - 100%
# Loss tensor(2.2527)
# Epoch 65 - 100%
# Loss tensor(2.1411)
# Epoch 66 - 100%
# Loss tensor(2.0717)
# Epoch 67 - 100%
# Loss tensor(2.1933)
# Epoch 68 - 100%
# Loss tensor(2.3284)
# Epoch 69 - 100%
# Loss tensor(2.1951)
# Epoch 70 - 100%
# Loss tensor(1.9813)
# Epoch 71 - 100%
# Loss tensor(2.3214)
# Epoch 72 - 100%
# Loss tensor(2.2141)
# Epoch 73 - 100%- 80%
# Loss tensor(1.9625)
# Epoch 74 - 100%
# Loss tensor(1.9736)
# Epoch 75 - 100%
# Loss tensor(2.2587)
# Epoch 76 - 100%
# Loss tensor(2.1745)
# Epoch 77 - 80% - 100%
# Loss tensor(2.1051)
# Epoch 78 - 100%
# Loss tensor(2.2346)
# Epoch 79 - 100%
# Loss tensor(2.1149)
# Epoch 80 - 100%
# Loss tensor(2.0980)
# Epoch 81 - 100%
# Loss tensor(2.2204)
# Epoch 82 - 100%
# Loss tensor(2.2620)
# Epoch 83 - 100%
# Loss tensor(2.1996)
# Epoch 84 - 100%
# Loss tensor(2.0171)
# Epoch 85 - 100%
# Loss tensor(2.0305)
# Epoch 86 - 100%
# Loss tensor(2.2247)
# Epoch 87 - 100%
# Loss tensor(2.0161)
# Epoch 88 - 100%
# Loss tensor(2.1016)
# Epoch 89 - 100%
# Loss tensor(2.0667)
# Epoch 90 - 100%- 40%
# Loss tensor(2.0538)
# Epoch 91 - 100%
# Loss tensor(2.1673)
# Epoch 92 - 100%
# Loss tensor(2.1249)
# Epoch 93 - 100%
# Loss tensor(1.9729)
# Epoch 94 - 100%
# Loss tensor(1.9297)
# Epoch 95 - 100%
# Loss tensor(2.0295)
# Epoch 96 - 100%
# Loss tensor(2.0952)
# Epoch 97 - 100%
# Loss tensor(2.2531)
# Epoch 98 - 100%- 80%
# Loss tensor(2.0303)
# Epoch 99 - 100%
# Loss tensor(1.9123)
# Epoch 100 - 100%
# Loss tensor(1.9306)
# Epoch 101 - 100%
# Loss tensor(2.2998)
# Epoch 102 - 100%- 80%
# Loss tensor(1.8767)
# Epoch 103 - 100%
# Loss tensor(2.1050)
# Epoch 104 - 100%
# Loss tensor(1.9131)
# Epoch 105 - 100%
# Loss tensor(1.9566)
# Epoch 106 - 100%
# Loss tensor(1.9536)
# Epoch 107 - 100%
# Loss tensor(1.9277)
# Epoch 108 - 100%
# Loss tensor(1.9907)
# Epoch 109 - 100%
# Loss tensor(2.1270)
# Epoch 110 - 100%
# Loss tensor(1.8826)
# Epoch 111 - 100%
# Loss tensor(1.9619)
# Epoch 112 - 100%
# Loss tensor(2.1229)
# Epoch 113 - 80% - 100%
# Loss tensor(1.8032)
# Epoch 114 - 100%
# Loss tensor(1.7913)
# Epoch 115 - 100%
# Loss tensor(2.2420)
# Epoch 116 - 100%
# Loss tensor(1.9981)
# Epoch 117 - 100%
# Loss tensor(1.9930)
# Epoch 118 - 100%
# Loss tensor(1.9969)
# Epoch 119 - 80% - 100%
# Loss tensor(2.1197)
# Epoch 120 - 100%
# Loss tensor(2.2916)
# Epoch 121 - 100%
# Loss tensor(2.0013)
# Epoch 122 - 100%
# Loss tensor(1.8773)
# Epoch 123 - 100%
# Loss tensor(2.0774)
# Epoch 124 - 100%
# Loss tensor(1.9711)
# Epoch 125 - 100%
# Loss tensor(1.8574)
# Epoch 126 - 100%
# Loss tensor(1.9909)
# Epoch 127 - 100%
# Loss tensor(1.9116)
# Epoch 128 - 100%
# Loss tensor(1.9800)
# Epoch 129 - 100%
# Loss tensor(1.9443)
# Epoch 130 - 100%
# Loss tensor(1.8758)
# Epoch 131 - 80% - 100%
# Loss tensor(1.8934)
# Epoch 132 - 100%
# Loss tensor(2.1427)
# Epoch 133 - 100%
# Loss tensor(1.8021)
# Epoch 134 - 100%
# Loss tensor(1.9304)
# Epoch 135 - 100%
# Loss tensor(1.9707)
# Epoch 136 - 100%
# Loss tensor(1.8720)
# Epoch 137 - 80% - 100%
# Loss tensor(1.9429)
# Epoch 138 - 100%
# Loss tensor(1.9570)
# Epoch 139 - 100%
# Loss tensor(1.8876)
# Epoch 140 - 100%
# Loss tensor(2.0503)
# 0.6059172749519348
#  WikiExample=(id=f000473b-bc85-49bd-9ced-24c744079e8c, text=['   ', 'als', 'wissen', 'werden', 'üblicherweise', 'einen', 'für', 'person', 'oder', 'gruppe', 'verfügbar', 'bestand', 'von', 'faktum', 'theorie', 'und', 'regel', 'verstehen', 'der', 'sich', 'durch', 'der', 'grad', 'an', 'gewissheit', 'auszeichnen', 'so', 'dass', 'von', 'sich', 'gültigkeit', 'bzw.', 'wahrheit', 'ausgehen', 'werden', 'bestimmt', 'form', 'der', 'wissen', 'beziehungsweise', 'der', 'speicherung', 'gelten', 'als', ' ', 'können', 'als', 'wissen', 'deklarieren', 'wahren', 'oder', 'falsch', 'vollständig', 'oder', 'unvollständig', 'mein', 'in', 'der', 'erkenntnistheorie', 'werden', 'wissen', 'traditionell', 'als', 'wahr', 'und', 'begründen', 'auffassung', 'bestimmen', 'der', 'problem', 'dies', 'bestimmung', 'werden', 'bis', 'in', 'der', 'gegenwart', 'diskutieren', 'da', 'in', 'der', 'direkt', 'erkenntnis', 'der', 'welt', 'der', 'gegenwärtig', 'sachverhalt', 'durch', 'der', 'biologisch', 'filtern', 'und', 'interpretieren', 'in', 'der', 'bewusstsein', 'kommen', 'sein', 'ich', 'einen', 'herausforderung', 'an', 'einen', 'theorie', 'der', 'wissen', 'ob', 'und', 'wie', 'der', 'wiedergabe', 'der', 'wirklichkeit', 'mehr', 'mein', 'können', 'als', 'einen', 'hypothetisch', 'modell', ' ', 'in', 'konstruktivistischen', 'und', 'ansatz', 'können', 'einzelne', 'faktum', 'so', 'nur', 'relativ', 'zu', 'ander', 'als', 'sicher', 'wissen', 'gelten', 'mit', 'der', 'ich', 'im', 'verbund', 'für', 'der', 'der', 'welt', 'repräsentieren', 'ich', 'lässt', 'sich', 'aber', 'immer', 'der', 'frage', 'nach', 'der', 'stellen', 'einzelner', 'modern', 'position', 'wie', 'der', 'oder', 'der', 'evolutionäre', 'erkenntnistheorie', 'ersetzen', 'dies', 'begründung', 'durch', 'bewährung', 'im', 'sozial', 'kontext', 'bzw.', 'durch', 'evolutionäre', 'tauglichkeit', 'im', 'werden', 'von', 'einer', 'als', 'wissen', 'anerkennen', 'was', 'ermöglichen', 'erfolgreich', 'der', 'und', 'der', 'nachgehen', 'in', 'der', 'evolutionären', 'erkenntnistheorie', 'sein', 'der', 'kriterium', 'für', 'wissen', 'biologisch', 'vorprogrammieren', 'und', 'unterliegen', 'mutation', 'und', 'selektion', 'all', 'drei', 'genannt', 'position', 'haben', 'gemeinsam', 'dass', 'ich', 'ein', 'einfluss', 'der', 'kontext', 'auf', 'der', 'semantik', 'zulassen', 'dagegen', 'lehnen', 'pragmatische', 'ein', 'solch', 'einfluss', 'ab', 'ich', 'argumentieren', 'dass', 'lediglich', 'aufgrund', 'pragmatisch', 'effekt', 'der', 'eindruck', 'entstehen', 'dass', 'der', 'von', 'wissenszuschreibungen', 'schwankung', 'unterliegen', 'dabei', 'werden', 'gemeinhin', 'einen', 'unterscheidung', 'zwischen', 'und', 'ausprägung', 'dies', 'position', 'machen', 'vertreten', 'der', 'meinung', 'dass', 'wissen', 'absolut', 'gewissheit', 'voraussetzen', 'dies', 'haben', 'zur', 'folge', 'dass', 'viel', 'wissenszuschreibungen', 'sich', 'als', 'semantisch', 'falsch', 'erweisen', 'weshalb', 'dies', 'position', 'auch', 'als', 'skeptisch', 'bezeichnen', 'werden', 'der', 'entgegen', 'vertreten', 'der', 'ansicht', 'dass', 'der', 'von', 'wissenszuschreibungen', 'wenig', 'strikt', 'sein', 'dies', 'vermeiden', 'der', 'skeptizismus', 'allerdings', 'müssen', 'so', 'auch', 'ganz', 'ander', 'pragmatische', 'effekt', 'behaupten', 'werden', ' ', 'in', 'der', 'jung', 'erkenntnistheoretischen', 'debatte', 'sein', 'versuch', 'einer', 'definition', 'in', 'der', 'hintergrund', 'treten', 'stattdessen', 'werden', 'ausführlich', 'diskutieren', 'wie', 'semantik', 'und', 'pragmatik', 'von', 'satz', 'der', 'form', 's', 'weiß', 'dass', 'p', 'sog.', 'wissenszuschreibungen', 'interagieren', 'und', 'welch', 'einfluss', 'kontext', 'dabei', 'ausüben', 'der', 'folgend', 'tabelle', 'stellen', 'der', 'fünf', 'wesentlich', 'position', 'in', 'dies', 'debatte', 'dar', 'aus', 'sicht', 'der', 'hängen', 'der', 'semantisch', 'wahrheit', 'direkt', 'von', 'bestimmen', 'eigenschaft', 'der', 'kontext', 'ab', 'in', 'der', 'der', 'wissenszuschreibung', 'tätigen', 'werden', 'zum', 'beispiel', 'werden', 'einen', 'dabe ...
# 0.5577741265296936
#  WikiExample=(id=c58f99f3-4d3a-4692-adfe-f486325a6b29, text=['künstlich', 'intelligenz', 'ki', 'auch', 'intelligenz', 'ai', 'bzw.', 'a.', 'i.', 'englisch', 'artificial', 'intelligence', 'ai', 'bzw.', 'a.', 'i.', 'sein', 'einen', 'teilgebiet', 'der', 'informatik', 'der', 'sich', 'mit', 'der', 'automatisierung', 'intelligent', 'verhalten', 'und', 'der', 'maschinell', 'lernen', 'befasst', 'der', 'begriff', 'sein', 'schwierig', 'zu', 'definieren', 'da', 'ich', 'bereits', 'an', 'einer', 'genau', 'definition', 'von', 'intelligenz', 'mangeln', 'dennoch', 'werden', 'ich', 'in', 'forschung', 'und', 'entwicklung', 'verwenden', ' ', 'meist', 'bezeichnen', 'künstliche', 'intelligenz', 'der', 'versuch', 'bestimmen', 'entscheidungsstrukturen', 'der', 'mensch', 'nachbilden', 'indem', 'z.', 'b.', 'einen', 'computer', 'so', 'bauen', 'und', 'programmieren', 'werden', 'dass', 'ich', 'relativ', 'eigenständig', 'problem', 'bearbeiten', 'können', 'oftmals', 'werden', 'damit', 'aber', 'auch', 'einen', 'intelligenz', 'bezeichnen', 'wobei', 'durch', 'meist', 'einfach', 'algorithmen', 'einen', 'intelligent', 'verhalten', 'simulieren', 'werden', 'soll', 'etwa', 'bei', 'in', 'computerspielen', ' ', 'der', 'präsident', 'von', 'microsoft', 'brad', 'smith', 'schlagen', 'vor', 'ein', 'verhaltenskodex', 'aufstellen', 'wie', 'etwa', 'einen', 'digital', 'konvention', 'um', 'risiko', 'der', 'künstliche', 'intelligenz', 'zu', 'verringern', 'der', 'peter', 'empfehlen', 'im', 'kontext', 'der', 'benutzung', 'und', 'programmierung', 'von', 'künstlicher', 'intelligenz', 'nicht', 'nur', 'der', 'digitale', 'kompetenz', 'der', 'beteiligte', 'zu', 'erhöhen', 'sondern', 'auch', 'auf', 'klassische', 'zu', 'setzen', 'um', 'mit', 'der', 'dazugehörig', 'herausforderung', 'zurechtkommen', 'sowie', 'der', 'fähigkeit', 'zur', 'unterscheidung', 'und', 'zur', 'erkennung', 'von', 'mehrdeutigkeit', 'zu', 'erhöhen', 'sein', 'kenntnis', 'aus', 'religion', 'literatur', 'mathematik', 'musik', 'und', 'sport', 'einen', 'gut', 'voraussetzung', 'der', 'deutschen', 'bundestag', 'haben', 'am', 'juni', 'einen', 'enquete-kommission', 'künstlich', 'intelligenz', 'gesellschaftlich', 'verantwortung', 'und', 'wirtschaftlich', 'potenziale', 'einsetzen', 'am', 'oktober', 'haben', 'der', 'kommission', 'mein', 'abschlussbericht', 'vorlegen', 'künstlich', 'intelligenz', 'sein', 'demnach', 'der', 'nächst', 'stufe', 'der', 'digitalisierung', 'unter', 'der', 'leitbild', 'einer', 'ki', 'werden', 'einen', 'gestaltung', 'der', 'entwicklung', 'fordern', 'so', 'dass', 'ki-anwendungen', 'vorrangig', 'auf', 'der', 'wohl', 'und', 'der', 'würde', 'der', 'mensch', 'ausrichten', 'sein', 'und', 'ein', 'gesellschaftlich', 'nutzen', 'bringen', 'um', 'einer', 'diskriminierung', 'von', 'mensch', 'entgegenwirken', 'brauchen', 'ich', 'wenn', 'ki', 'über', 'mensch', 'urteilen', 'ein', 'anspruch', 'auf', 'transparenz', 'nachvollziehbarkeit', 'und', 'erklärbarkeit', 'von', 'damit', 'einen', 'gerichtlich', 'überprüfung', 'automatisiert', 'entscheidung', 'möglich', 'sein', 'viel', 'alt', 'methode', 'der', 'in', 'der', 'ki', 'entwickeln', 'werden', 'basieren', 'auf', 'heuristisch', 'lösungsverfahren', 'in', 'jung', 'zeit', 'spielen', 'mathematisch', 'fundieren', 'ansatz', 'aus', 'der', 'statistik', 'der', 'mathematisch', 'programmierung', 'und', 'der', 'approximationstheorie', 'einen', 'bedeutend', 'rolle', ' ', 'der', 'methode', 'der', 'ki', 'lassen', 'sich', 'grob', 'in', 'zwei', 'dimension', 'einordnen', 'symbolische', 'vs.', 'neuronal', 'ki', 'und', 'vs.', 'methode', 'der', 'zusammenhang', 'veranschaulichen', 'der', 'folgend', 'grafik', '  ', 'der', 'neuronale', 'ki', 'verfolgen', 'ein', 'bottom-up-ansatz', 'und', 'mögen', 'der', 'menschliche', 'gehirn', 'möglichst', 'präzise', 'nachbilden', 'der', 'symbolische', 'ki', 'verfolgen', 'umkehren', 'ein', 'top-down-ansatz', 'und', 'nähern', 'sich', 'der', 'von', 'einer', 'begrifflich', 'ebene', 'her', 'der', 'orientieren', 'sich', 'so', 'nah', 'wie', 'möglich', 'an', 'der', 'tatsäc ...

# %%
# Translation of some paragraphs from https://en.wikipedia.org/wiki/Cryptography
# The two documents most similar to it are https://de.wikipedia.org/wiki/Network_Access_Control and 
# https://de.wikipedia.org/wiki/Schl%C3%BCsselraum_(Kryptologie)
doc2 = Document(
    id = '',
    title = 'Test',
    excerpt = """
    Kryptographie oder Kryptologie ist die Praxis und das Studium von Techniken zur sicheren Kommunikation in 
    Gegenwart von gegnerischem Verhalten.[2] Allgemeiner gesagt geht es bei der Kryptographie um den Aufbau und die 
    Analyse von Protokollen, die verhindern, dass Dritte oder die Öffentlichkeit private Nachrichten lesen;[3] 
    verschiedene Aspekte der Informationssicherheit wie Datenvertraulichkeit, Datenintegrität, Authentifizierung 
    und Nichtabstreitbarkeit[4] sind von zentraler Bedeutung für moderne Kryptographie. Die moderne Kryptographie 
    existiert an der Schnittstelle der Disziplinen Mathematik, Informatik, Elektrotechnik, Kommunikationswissenschaft
    und Physik. Zu den Anwendungen der Kryptographie gehören der elektronische Handel, chipbasierte Zahlungskarten, 
    digitale Währungen, Computerpasswörter und militärische Kommunikation.
    """,
    source='mediawiki',
    sections=[
        Section(id='', title='', position='', paragraphs=[Paragraph(id='', text="""
        Der Data Encryption Standard (DES) und der Advanced Encryption Standard (AES) sind Blockchiffre-Designs,
        die von der US-Regierung als Kryptographie-Standards bezeichnet wurden (obwohl die Bezeichnung von DES nach
        der Annahme des AES endgültig zurückgezogen wurde).[30] Trotz seiner Verabschiedung als offizieller Standard
        bleibt DES (insbesondere seine noch zugelassene und viel sicherere Triple-DES-Variante) sehr beliebt; Es wird 
        in einer Vielzahl von Anwendungen verwendet, von der ATM-Verschlüsselung[31] über den E-Mail-Datenschutz[32] bis
        hin zum sicheren Fernzugriff.[33] Viele andere Blockchiffren wurden mit erheblichen Qualitätsunterschieden 
        entwickelt und veröffentlicht. Viele, sogar einige, die von fähigen Praktizierenden entworfen wurden, wurden 
        gründlich gebrochen, wie z. B. FEAL.[4][34]
        """)]),
        Section(id='', title='', position='', paragraphs=[Paragraph(id='', text="""
        Kryptosysteme mit symmetrischem Schlüssel verwenden denselben Schlüssel zum Verschlüsseln und 
        Entschlüsseln einer Nachricht, obwohl eine Nachricht oder eine Gruppe von Nachrichten einen anderen 
        Schlüssel als andere haben kann. Ein wesentlicher Nachteil symmetrischer Chiffren ist die für deren sichere
        Verwendung notwendige Schlüsselverwaltung. Jedes einzelne Paar kommunizierender Parteien muss idealerweise
        einen anderen Schlüssel teilen, und vielleicht auch für jeden ausgetauschten Chiffretext. Die Anzahl der 
        erforderlichen Schlüssel steigt mit dem Quadrat der Anzahl der Netzwerkmitglieder, was sehr schnell komplexe
        Schlüsselverwaltungsschemata erfordert, um sie alle konsistent und geheim zu halten.
        """)]),
        Section(id='', title='', position='', paragraphs=[Paragraph(id='', text="""
        In Kryptosystemen mit öffentlichem Schlüssel kann der öffentliche Schlüssel frei verteilt werden, 
        während sein gepaarter privater Schlüssel geheim bleiben muss. In einem Verschlüsselungssystem mit 
        öffentlichem Schlüssel wird der öffentliche Schlüssel zur Verschlüsselung verwendet, während der private oder
        geheime Schlüssel zur Entschlüsselung verwendet wird. Obwohl Diffie und Hellman kein solches System finden konnten,
        zeigten sie, dass Kryptographie mit öffentlichem Schlüssel tatsächlich möglich war, indem sie das 
        Diffie-Hellman-Schlüsselaustauschprotokoll vorstellten, eine Lösung, die heute in der sicheren Kommunikation weit
        verbreitet ist, um es zwei Parteien zu ermöglichen, sich heimlich auf ein gemeinsamer Verschlüsselungsschlüssel.[27]
        Der X.509-Standard definiert das am häufigsten verwendete Format für Public-Key-Zertifikate.[41]
        """)])
    ]
)
vec = dm_service.infer_vector(doc2)
dists, indices = dm_service.most_similar(vec, topn=2)
for i, dist in enumerate(dists):
    print(f"{dist.item()}\n {dm_service._dataset[indices[i].item()]}")
# Out:
# Epoch 1 - 100%
# Loss tensor(2.7748)
# Epoch 2 - 100%
# Loss tensor(2.5954)
# Epoch 3 - 100%
# Loss tensor(2.7110)
# Epoch 4 - 100%
# Loss tensor(2.6240)
# Epoch 5 - 100%
# Loss tensor(2.5972)
# Epoch 6 - 100%
# Loss tensor(2.8338)
# Epoch 7 - 100%
# Loss tensor(2.7153)
# Epoch 8 - 100%
# Loss tensor(2.7269)
# Epoch 9 - 100%
# Loss tensor(2.4684)
# Epoch 10 - 100%
# Loss tensor(2.6400)
# Epoch 11 - 100%
# Loss tensor(2.4925)
# Epoch 12 - 100%
# Loss tensor(2.4243)
# Epoch 13 - 100%
# Loss tensor(2.3742)
# Epoch 14 - 100%
# Loss tensor(2.5705)
# Epoch 15 - 100%
# Loss tensor(2.4491)
# Epoch 16 - 100%
# Loss tensor(2.3955)
# Epoch 17 - 100%
# Loss tensor(2.3616)
# Epoch 18 - 100%
# Loss tensor(2.5013)
# Epoch 19 - 100%
# Loss tensor(2.3657)
# Epoch 20 - 100%
# Loss tensor(2.2315)
# Epoch 21 - 100%- 67%
# Loss tensor(2.2516)
# Epoch 22 - 100%
# Loss tensor(2.4630)
# Epoch 23 - 100%
# Loss tensor(2.3484)
# Epoch 24 - 100%
# Loss tensor(2.3237)
# Epoch 25 - 100%
# Loss tensor(2.2165)
# Epoch 26 - 100%
# Loss tensor(2.2307)
# Epoch 27 - 100%
# Loss tensor(2.2911)
# Epoch 28 - 100%
# Loss tensor(2.4003)
# Epoch 29 - 100%
# Loss tensor(2.1025)
# Epoch 30 - 67% - 100%
# Loss tensor(2.2896)
# Epoch 31 - 67% - 100%
# Loss tensor(2.1995)
# Epoch 32 - 100%
# Loss tensor(2.2777)
# Epoch 33 - 100%
# Loss tensor(2.2019)
# Epoch 34 - 100%
# Loss tensor(2.2616)
# Epoch 35 - 100%
# Loss tensor(2.1013)
# Epoch 36 - 100%
# Loss tensor(1.9405)
# Epoch 37 - 100%
# Loss tensor(2.2350)
# Epoch 38 - 100%
# Loss tensor(2.2316)
# Epoch 39 - 100%
# Loss tensor(2.1578)
# Epoch 40 - 100%
# Loss tensor(2.1463)
# Epoch 41 - 100%
# Loss tensor(2.1579)
# Epoch 42 - 100%
# Loss tensor(2.1009)
# Epoch 43 - 100%
# Loss tensor(2.2570)
# Epoch 44 - 100%
# Loss tensor(2.0347)
# Epoch 45 - 100%
# Loss tensor(2.1299)
# Epoch 46 - 100%
# Loss tensor(2.0371)
# Epoch 47 - 100%
# Loss tensor(2.1035)
# Epoch 48 - 100%
# Loss tensor(2.1694)
# Epoch 49 - 100%
# Loss tensor(2.0789)
# Epoch 50 - 100%
# Loss tensor(1.9498)
# Epoch 51 - 100%
# Loss tensor(2.0774)
# Epoch 52 - 100%
# Loss tensor(2.1585)
# Epoch 53 - 100%
# Loss tensor(2.1670)
# Epoch 54 - 100%
# Loss tensor(1.9448)
# Epoch 55 - 100%
# Loss tensor(1.8855)
# Epoch 56 - 100%
# Loss tensor(1.9528)
# Epoch 57 - 67% - 100%
# Loss tensor(1.8875)
# Epoch 58 - 100%
# Loss tensor(2.0552)
# Epoch 59 - 100%
# Loss tensor(1.9269)
# Epoch 60 - 100%
# Loss tensor(1.8688)
# Epoch 61 - 100%
# Loss tensor(1.9101)
# Epoch 62 - 100%
# Loss tensor(1.9290)
# Epoch 63 - 100%
# Loss tensor(1.9049)
# Epoch 64 - 100%
# Loss tensor(2.3143)
# Epoch 65 - 100%
# Loss tensor(1.7152)
# Epoch 66 - 100%
# Loss tensor(1.8479)
# Epoch 67 - 100%
# Loss tensor(1.9969)
# Epoch 68 - 100%
# Loss tensor(1.7727)
# Epoch 69 - 100%
# Loss tensor(1.9248)
# Epoch 70 - 100%
# Loss tensor(2.0188)
# Epoch 71 - 100%
# Loss tensor(1.6992)
# Epoch 72 - 100%
# Loss tensor(1.9840)
# Epoch 73 - 100%
# Loss tensor(1.8359)
# Epoch 74 - 100%
# Loss tensor(1.8601)
# Epoch 75 - 100%
# Loss tensor(1.8237)
# Epoch 76 - 100%
# Loss tensor(1.8759)
# Epoch 77 - 100%
# Loss tensor(1.8620)
# Epoch 78 - 100%
# Loss tensor(1.7618)
# Epoch 79 - 100%
# Loss tensor(1.8420)
# Epoch 80 - 100%
# Loss tensor(1.9412)
# Epoch 81 - 100%
# Loss tensor(1.7068)
# Epoch 82 - 100%
# Loss tensor(1.7482)
# Epoch 83 - 100%
# Loss tensor(1.9387)
# Epoch 84 - 100%
# Loss tensor(1.7020)
# Epoch 85 - 100%
# Loss tensor(1.6145)
# Epoch 86 - 100%
# Loss tensor(1.9633)
# Epoch 87 - 100%
# Loss tensor(1.8804)
# Epoch 88 - 100%
# Loss tensor(1.7788)
# Epoch 89 - 100%
# Loss tensor(1.7060)
# Epoch 90 - 100%
# Loss tensor(2.0096)
# Epoch 91 - 100%
# Loss tensor(1.8088)
# Epoch 92 - 100%
# Loss tensor(2.0485)
# Epoch 93 - 100%
# Loss tensor(1.7444)
# Epoch 94 - 100%
# Loss tensor(1.7945)
# Epoch 95 - 100%
# Loss tensor(1.8479)
# Epoch 96 - 100%
# Loss tensor(1.8210)
# Epoch 97 - 100%
# Loss tensor(1.7580)
# Epoch 98 - 67% - 100%
# Loss tensor(1.7062)
# Epoch 99 - 100%
# Loss tensor(1.8015)
# Epoch 100 - 100%
# Loss tensor(1.7694)
# Epoch 101 - 100%
# Loss tensor(1.8821)
# Epoch 102 - 100%
# Loss tensor(1.9241)
# Epoch 103 - 100%
# Loss tensor(1.7038)
# Epoch 104 - 100%
# Loss tensor(1.6402)
# Epoch 105 - 100%
# Loss tensor(1.6362)
# Epoch 106 - 100%
# Loss tensor(1.7526)
# Epoch 107 - 100%
# Loss tensor(1.8385)
# Epoch 108 - 100%
# Loss tensor(1.8903)
# Epoch 109 - 100%- 67%
# Loss tensor(1.7748)
# Epoch 110 - 100%- 67%
# Loss tensor(1.5946)
# Epoch 111 - 100%
# Loss tensor(1.5710)
# Epoch 112 - 100%
# Loss tensor(1.5566)
# Epoch 113 - 100%
# Loss tensor(1.7012)
# Epoch 114 - 100%
# Loss tensor(1.7840)
# Epoch 115 - 100%
# Loss tensor(1.7602)
# Epoch 116 - 100%
# Loss tensor(1.6758)
# Epoch 117 - 100%
# Loss tensor(1.6840)
# Epoch 118 - 100%
# Loss tensor(1.8763)
# Epoch 119 - 100%
# Loss tensor(1.5749)
# Epoch 120 - 100%
# Loss tensor(1.6423)
# Epoch 121 - 100%
# Loss tensor(1.7492)
# Epoch 122 - 100%
# Loss tensor(1.6586)
# Epoch 123 - 100%
# Loss tensor(1.6701)
# Epoch 124 - 100%
# Loss tensor(1.6951)
# Epoch 125 - 100%
# Loss tensor(1.6402)
# Epoch 126 - 100%
# Loss tensor(1.6785)
# Epoch 127 - 100%
# Loss tensor(1.6453)
# Epoch 128 - 100%
# Loss tensor(1.4139)
# Epoch 129 - 100%
# Loss tensor(1.4905)
# Epoch 130 - 100%
# Loss tensor(1.6129)
# Epoch 131 - 100%
# Loss tensor(1.7077)
# Epoch 132 - 100%
# Loss tensor(1.6181)
# Epoch 133 - 100%
# Loss tensor(1.5926)
# Epoch 134 - 100%
# Loss tensor(1.6602)
# Epoch 135 - 100%
# Loss tensor(1.5675)
# Epoch 136 - 67% - 100%
# Loss tensor(1.4873)
# Epoch 137 - 100%- 67%
# Loss tensor(1.4621)
# Epoch 138 - 100%
# Loss tensor(1.7706)
# Epoch 139 - 100%
# Loss tensor(1.5120)
# Epoch 140 - 100%
# Loss tensor(1.5461)
# 0.47928425669670105
#  WikiExample=(id=9e023aa5-3436-42a1-b2cd-3d2929c4a5b2, text=['network', 'access', 'control', 'nac', 'deutschen', 'sein', 'einen', 'technik', 'der', 'der', 'abwehr', 'von', 'virus', 'wurm', 'und', 'zugriffen', 'aus', 'der', 'netzwerk', 'heraus', 'unterstützen', 'mit', 'nac', 'werden', 'endgeräte', 'während', 'der', 'authentifizierung', 'auf', 'prüfen', 'sein', 'z.', 'b.', 'der', 'virenscanner', 'nicht', 'aktuell', 'oder', 'fehlen', 'der', 'der', 'neueste', 'werden', 'der', 'betroffen', 'endgerät', 'unter', 'quarantäne', 'stellen', 'und', 'mit', 'aktuell', 'updates', 'versorgen', 'bis', 'ich', 'wieder', 'der', 'geltend', 'sicherheitsrichtlinien', 'entsprechen', 'anfang', 'verteilen', 'sich', 'der', 'dafür', 'erforderlich', 'funktion', 'auf', 'netzwerkkomponenten', 'wie', 'router', 'und', 'switches', 'auf', 'appliances', 'können', 'sämtliche', 'funktionalitäten', 'auch', 'bündeln', 'vorhalten', 'werden', 'werden', 'fremd', 'gerät', 'erkennen', 'so', 'werden', 'dies', 'durch', 'verschieden', 'technologie', 'in', 'der', 'kommunikation', 'stören', 'oder', 'zum', 'beispiel', 'auf', 'einen', 'umleiten', 'teilweis', 'kommen', 'dafür', 'sogar', 'arp-spoofing', 'zum', 'einsatz', 'was', 'eigentlich', 'eher', 'einen', 'sein', 'bei', 'dies', 'technologie', 'werden', 'der', 'netzwerk', 'nach', 'verwenden', 'ip-adressen', 'gescannt', 'indem', 'der', 'adressräume', 'werden', 'oder', 'der', 'der', 'router', 'auslesen', 'werden', 'dadurch', 'erkannt', 'endgeräte', 'werden', 'dann', 'in', 'der', 'regel', 'durch', 'weit', 'scans', 'genau', 'identifizieren', 'um', 'zu', 'überprüfen', 'ob', 'ich', 'sich', 'um', 'bekannt', 'und', 'zugelassen', 'gerät', 'handeln', 'dieser', 'status', 'können', 'remote', 'oder', 'ermitteln', 'werden', 'remote', 'werden', 'der', 'endgeräte', 'dabei', 'vor', 'alle', 'per', 'wmi', 'snmp', 'oder', 'gescannt', 'ebenfalls', 'möglich', 'sein', 'abfrage', 'per', 'oder', 'javascript', 'agent', 'haben', 'mit', 'entsprechend', 'lokal', 'rechte', 'der', 'möglichkeit', 'erheblich', 'tiefgreifend', 'zu', 'prüfen', 'und', 'sich', 'dabei', 'nicht', 'nur', 'auf', 'oder', 'apis', 'von', 'ander', 'hersteller', 'zu', 'verlassen', 'so', 'können', 'z.', 'b.', 'per', 'hashwert', 'mit', 'vergleichen', 'werden', 'anstatt', 'nur', 'zu', 'prüfen', 'ob', 'der', 'installation', 'ein', 'patches', 'zwar', 'in', 'der', 'registrierungsdatenbank', 'eintragen', 'werden', 'während', 'tatsächlich', 'der', 'installation', 'fehlschlagen', 'sein', 'network', 'access', 'control', 'erhalten', 'also', 'einen', 'zentrale', 'bedeutung', 'in', 'da', 'der', 'möglichkeit', 'der', 'reaktion', 'hoch', 'effektiv', 'sein', 'und', 'bei', 'direkt', 'von', 'extrem', 'schnellen', 'umsetzen', 'werden', 'können', 'der', 'sicher', 'variante', 'sein', 'dabei', 'der', 'prüfung', 'vor', 'der', 'zulassung', 'zum', 'netzwerk', 'was', 'jedoch', 'in', 'der', 'praxis', 'häufig', 'schwer', 'durchsetzen', 'sein', 'häufig', 'werden', 'der', 'prüfung', 'daher', 'ausführen', 'und', 'fahren', 'im', 'bedarfsfall', 'damit', 'zu', 'einer', 'reaktiv', 'der', 'system', 'ergänzend', 'geben', 'ich', 'unterschiedlich', 'strategie', 'was', 'der', 'zeitpunkt', 'der', 'prüfung', 'angehen', 'während', 'einen', 'agent', 'der', 'status', 'permanent', 'prüfen', 'können', 'und', 'so', 'z.', 'b.', 'auch', 'vor', 'der', 'netzwerkverbindung', 'bereits', 'über', 'der', 'zustand', 'der', 'endgerätes', 'bescheid', 'weiß', 'müssen', 'prüfung', 'zu', 'bestimmen', 'zeit', 'in', 'bestimmen', 'situation', 'und', 'oder', 'zyklisch', 'ausführen', 'werden', 'in', 'verbindung', 'mit', 'network', 'access', 'control', 'beziehen', 'sich', 'compliance', 'in', 'der', 'regel', 'auf', 'wobei', 'auch', 'hier', 'der', 'ziel', 'bzw.', 'der', 'anforderung', 'unterschieden', 'werden', 'müssen', 'so', 'sein', 'in', 'dies', 'zusammenhang', 'vor', 'alle', 'interessant', 'ob', 'der', 'endgeräte', 'der', 'sicherheitsrichtlinien', 'entsprechen', 'und', 'dahingehen', 'sein', 'der', 'richtlinie', 'beziehen', 'sich', 'dann', 'vor', 'alle', ' ...
# 0.46619588136672974
#  WikiExample=(id=72382c71-0dcf-4576-ad4e-3804a2f3d145, text=['schlüsselraum', 'sein', 'einen', 'begriff', 'aus', 'der', 'kryptographie', 'und', 'bezeichnen', 'der', 'menge', 'all', 'für', 'einen', 'verschlüsselungsverfahren', 'möglich', 'schlüssel', 'der', 'größe', 'der', 'schlüsselraums', 'beziffern', 'der', 'anzahl', 'all', 'schlüssel', 'und', 'werden', 'knapp', 'auch', 'als', 'der', 'schlüsselanzahl', 'bezeichnen', 'ein', 'maßen', 'der', 'größe', 'der', 'schlüsselraums', 'sein', 'der', 'schlüssellänge', 'der', 'in', 'bit', 'angeben', 'werden', 'ferner', 'geben', 'ich', 'schlüsselraum', 'als', 'bezeichnung', 'für', 'einen', 'zimmer', 'in', 'der', 'schlüssel', 'aufbewahren', 'werden', 'beispielsweise', 'an', 'mit', 'wieder', 'ander', 'bedeutung', 'werden', 'schlüsselraum', 'auch', 'in', 'der', 'geographie', 'raumplanung', 'oder', 'benutzen', 'dort', 'bezeichnen', 'man', 'damit', 'einen', 'zone', 'oder', 'ein', 'geographisch', 'raum', 'der', 'einen', 'etwa', 'zur', 'industrie-', 'oder', 'oder', 'zur', 'zuordnen', 'werden', 'nicht', 'verwechseln', 'werden', 'dürfen', 'dies', 'bedeutung', 'der', 'begriff', 'mit', 'einer', 'schlüsselraum', 'bild', 'auch', 'selten', 'auch', 'in', 'der', 'nachricht', 'ver-', 'oder', 'entschlüsseln', 'werden', 'im', 'allgemein', 'formulieren', 'also', 'schlüsseln', 'werden', ' ', 'eine', 'ausreichend', 'sein', 'einen', 'wichtig', 'und', 'notwendige', 'bedingung', 'für', 'der', 'sicherheit', 'ein', 'kryptographischen', 'verfahren', 'ich', 'allein', 'bieten', 'jedoch', 'noch', 'kein', 'hinreichend', 'schutz', 'vor', 'unbefugter', 'entzifferung', 'knacken', 'bei', 'kryptographisch', 'schwach', 'verschlüsselungsverfahren', 'können', 'ich', 'einer', 'angreifer', 'gelingen', 'abkürzung', 'zu', 'entdecken', 'der', 'ich', 'der', 'finden', 'der', 'schlüssel', 'ermöglichen', 'ohne', 'dazu', 'all', 'möglich', 'schlüssel', 'ausprobieren', 'zu', 'müssen', 'ein', 'beispiel', 'dafür', 'sein', 'der', 'mustersuche', 'als', 'kryptanalytische', 'angriffsmethode', 'auf', 'per', 'monoalphabetische', 'substitution', 'verschlüsseln', 'geheimtexte', 'obwohl', 'hier', 'der', 'schlüsselraum', 'bei', 'einer', 'geheimalphabet', 'mit', 'beispielsweise', 'zeichen', 'entsprechen', 'der', 'großbuchstabe', 'der', 'üblich', 'lateinisch', 'alphabet', 'fakultät', 'betragen', 'der', 'sein', 'ungefähr', 'möglich', 'schlüssel', 'gelingen', 'der', 'entzifferung', 'von', 'derart', 'verschlüsseln', 'text', 'relativ', 'mühelos', 'und', 'ohne', 'erschöpfend', 'suche', 'exhaustion'])
